# %% [markdown]
# # Clasificación de Células Sanguíneas
#
# En el proceso de diagnóstico de enfermedades, el estudio de la cantidad de células sanguíneas juega un papel importante para determinar factores que explican una enfermedad. En esta tarea, la idea es implementar el modelo de deep-learning más efectivo posible para clasificar células sanguíneas. Las clases de células sanguíneas son: [Eosinophil, Lymphocyte, Monocyte, Neutrophil]

# %%
#Instalamos el paquete gdown para poder descargar el dataset desde el gdrive
# !pip install gdown
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: gdown in /usr/local/lib/python3.7/dist-packages (4.4.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from gdown) (1.15.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (from gdown) (4.6.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from gdown) (4.64.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from gdown) (3.8.0)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.7/dist-packages (from gdown) (2.23.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->gdown) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->gdown) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->gdown) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->gdown) (2022.9.24)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->gdown) (1.7.1)

# %%
#Descargamos el dataset
import gdown
output = 'blood.zip'
gdown.download(id='1CUQjT45tJmqNv_p2HcDkr4Z-IDQEbRg3', output=output, quiet=False)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1CUQjT45tJmqNv_p2HcDkr4Z-IDQEbRg3
# To: /content/blood.zip
# 100%|██████████| 105M/105M [00:00<00:00, 174MB/s]
# 'blood.zip'

# %%
# Descomprimimos el dataset
# !unzip blood.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: images/TRAIN/MONOCYTE/_0_4446.jpeg
#   inflating: images/TRAIN/MONOCYTE/_0_4528.jpeg
#   inflating: images/TRAIN/MONOCYTE/_0_453.jpeg
#   inflating: images/TRAIN/MONOCYTE/_0_4560.jpeg
#   inflating: images/TRAIN/MONOCYTE/_0_4563.jpeg
#   inflating: images/TRAIN/MONOCYTE/_0_4650.jpeg
#   inflating: images/TRAIN/MONOCYTE/_0_4667.jpeg
#   inflating: images/TRAIN/MONOCYTE/_0_4715.jpeg
#   inflating: images/TRAIN/MONOCYTE/_0_4745.jpeg
#   inflating: images/TRAIN/MONOCYTE/_0_4762.jpeg
#   inflating: images/TRAIN/MONOCYTE/_0_4778.jpeg
#   inflating: images/TRAIN/MONOCYTE/_0_4791.jpeg
#   inflating: images/TRAIN/MONOCYTE/_0_4862.jpeg
#   inflating: images/TRAIN/MONOCYTE/_0_4872.jpeg
#   inflating: images/TRAIN/MONOCYTE/_0_4881.jpeg
#   inflating: images/TRAIN/MONOCYTE/_0_4884.jpeg
#   inflating: images/TRAIN/MONOCYTE/_0_4925.jpeg
#   inflating: images/TRAIN/MONOCYTE/_0_494.jpeg
#   inflating: images/TRAIN/MONOCYTE/_0_5029.jpeg
#   inflating: images/TRAIN/MONOCYTE/_0_5074.jpeg
#   inflating: images/TRAIN/MONOCYTE/_0_508.jpeg
#   inflating: images/TRAIN/MONOCYTE/_0_5081.jpeg
#   inflating: images/TRAIN/MONOCYTE/_0_5144.jpeg
#   inflating: images/TRAIN/MONOCYTE/_0_5156.jpeg
#   inflating: images/TRAIN/MONOCYTE/_0_5200.jpeg
#   inflating: images/TRAIN/MONOCYTE/_0_5209.jpeg
#   inflating: images/TRAIN/MONOCYTE/_0_5226.jpeg
#   inflating: images/TRAIN/MONOCYTE/_0_5241.jpeg
#   inflating: images/TRAIN/MONOCYTE/_0_527.jpeg
#   inflating: images/TRAIN/MONOCYTE/_0_5327.jpeg
#   inflating: images/TRAIN/MONOCYTE/_0_5448.jpeg
#   inflating: images/TRAIN/MONOCYTE/_0_5486.jpeg
#   inflating: images/TRAIN/MONOCYTE/_0_563.jpeg
#   inflating: images/TRAIN/MONOCYTE/_0_5674.jpeg
#   inflating: images/TRAIN/MONOCYTE/_0_5709.jpeg
#   inflating: images/TRAIN/MONOCYTE/_0_5796.jpeg
#   inflating: images/TRAIN/MONOCYTE/_0_5848.jpeg
#   inflating: images/TRAIN/MONOCYTE/_0_5888.jpeg
#   inflating: images/TRAIN/MONOCYTE/_0_5942.jpeg
#   inflating: images/TRAIN/MONOCYTE/_0_6017.jpeg
#   inflating: images/TRAIN/MONOCYTE/_0_6035.jpeg
#   inflating: images/TRAIN/MONOCYTE/_0_620.jpeg
#   inflating: images/TRAIN/MONOCYTE/_0_6229.jpeg
#   inflating: images/TRAIN/MONOCYTE/_0_6256.jpeg
#   inflating: images/TRAIN/MONOCYTE/_0_635.jpeg
#   inflating: images/TRAIN/MONOCYTE/_0_6357.jpeg
#   inflating: images/TRAIN/MONOCYTE/_0_6358.jpeg
#   inflating: images/TRAIN/MONOCYTE/_0_6482.jpeg
#   inflating: images/TRAIN/MONOCYTE/_0_6524.jpeg
#   inflating: images/TRAIN/MONOCYTE/_0_6593.jpeg
#   inflating: images/TRAIN/MONOCYTE/_0_6675.jpeg
#   inflating: images/TRAIN/MONOCYTE/_0_671.jpeg
#   inflating: images/TRAIN/MONOCYTE/_0_6807.jpeg
#   inflating: images/TRAIN/MONOCYTE/_0_6917.jpeg
#   inflating: images/TRAIN/MONOCYTE/_0_6934.jpeg
#   inflating: images/TRAIN/MONOCYTE/_0_7025.jpeg
#   inflating: images/TRAIN/MONOCYTE/_0_7180.jpeg
#   inflating: images/TRAIN/MONOCYTE/_0_730.jpeg
#   inflating: images/TRAIN/MONOCYTE/_0_7378.jpeg
#   inflating: images/TRAIN/MONOCYTE/_0_7387.jpeg
#   inflating: images/TRAIN/MONOCYTE/_0_7456.jpeg
#   inflating: images/TRAIN/MONOCYTE/_0_7573.jpeg
#   inflating: images/TRAIN/MONOCYTE/_0_760.jpeg
#   inflating: images/TRAIN/MONOCYTE/_0_7602.jpeg
#   inflating: images/TRAIN/MONOCYTE/_0_7639.jpeg
#   inflating: images/TRAIN/MONOCYTE/_0_773.jpeg
#   inflating: images/TRAIN/MONOCYTE/_0_7793.jpeg
#   inflating: images/TRAIN/MONOCYTE/_0_780.jpeg
#   inflating: images/TRAIN/MONOCYTE/_0_7814.jpeg
#   inflating: images/TRAIN/MONOCYTE/_0_791.jpeg
#   inflating: images/TRAIN/MONOCYTE/_0_7952.jpeg
#   inflating: images/TRAIN/MONOCYTE/_0_7977.jpeg
#   inflating: images/TRAIN/MONOCYTE/_0_8135.jpeg
#   inflating: images/TRAIN/MONOCYTE/_0_8206.jpeg
#   inflating: images/TRAIN/MONOCYTE/_0_8218.jpeg
#   inflating: images/TRAIN/MONOCYTE/_0_8273.jpeg
#   inflating: images/TRAIN/MONOCYTE/_0_8331.jpeg
#   inflating: images/TRAIN/MONOCYTE/_0_8439.jpeg
#   inflating: images/TRAIN/MONOCYTE/_0_8508.jpeg
#   inflating: images/TRAIN/MONOCYTE/_0_8643.jpeg
#   inflating: images/TRAIN/MONOCYTE/_0_8999.jpeg
#   inflating: images/TRAIN/MONOCYTE/_0_9112.jpeg
#   inflating: images/TRAIN/MONOCYTE/_0_9144.jpeg
#   inflating: images/TRAIN/MONOCYTE/_0_9189.jpeg
#   inflating: images/TRAIN/MONOCYTE/_0_9207.jpeg
#   inflating: images/TRAIN/MONOCYTE/_0_9218.jpeg
#   inflating: images/TRAIN/MONOCYTE/_0_9224.jpeg
#   inflating: images/TRAIN/MONOCYTE/_0_9258.jpeg
#   inflating: images/TRAIN/MONOCYTE/_0_9282.jpeg
#   inflating: images/TRAIN/MONOCYTE/_0_9309.jpeg
#   inflating: images/TRAIN/MONOCYTE/_0_9363.jpeg
#   inflating: images/TRAIN/MONOCYTE/_0_9393.jpeg
#   inflating: images/TRAIN/MONOCYTE/_0_9591.jpeg
#   inflating: images/TRAIN/MONOCYTE/_0_9601.jpeg
#   inflating: images/TRAIN/MONOCYTE/_0_9654.jpeg
#   inflating: images/TRAIN/MONOCYTE/_0_9679.jpeg
#   inflating: images/TRAIN/MONOCYTE/_0_9712.jpeg
#   inflating: images/TRAIN/MONOCYTE/_0_9757.jpeg
#   inflating: images/TRAIN/MONOCYTE/_0_9986.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_1029.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_1087.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_1188.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_1192.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_1326.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_1338.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_1496.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_155.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_1579.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_1604.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_1622.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_1662.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_1696.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_1741.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_1844.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_1874.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_205.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_2132.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_22.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_2237.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_2294.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_2316.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_2323.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_2403.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_2456.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_2478.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_259.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_2614.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_2792.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_283.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_2858.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_2883.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_2890.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_2935.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_2943.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_3007.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_3016.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_3021.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_3093.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_315.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_3239.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_3357.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_3405.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_3443.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_3633.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_3760.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_3775.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_3888.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_407.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_4108.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_4183.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_4307.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_4312.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_4375.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_449.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_4504.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_4514.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_4535.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_4539.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_4567.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_461.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_4634.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_4757.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_4783.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_4832.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_4862.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_4904.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_4956.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_4994.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_5027.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_5080.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_51.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_5113.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_5143.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_5158.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_5196.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_5349.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_5433.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_5462.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_5593.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_5668.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_5716.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_5720.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_5790.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_5814.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_584.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_5896.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_5909.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_5981.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_5992.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_6025.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_6082.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_6104.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_6136.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_6208.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_6272.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_6277.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_6302.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_6375.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_6378.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_6388.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_6441.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_6450.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_6505.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_6585.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_6734.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_6788.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_7153.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_7297.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_7425.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_7428.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_7445.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_7695.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_7739.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_7740.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_7799.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_7865.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_7966.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_803.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_8071.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_8084.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_8151.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_821.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_8239.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_8247.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_8324.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_8328.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_8335.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_8348.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_8351.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_8577.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_8600.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_8622.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_8676.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_8696.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_8854.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_8922.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_9029.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_9087.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_9152.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_9198.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_9250.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_929.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_9306.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_9376.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_9408.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_949.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_970.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_9733.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_9758.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_9818.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_9828.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_9964.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_9984.jpeg
#   inflating: images/TRAIN/MONOCYTE/_10_9991.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_1041.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_1054.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_1068.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_1120.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_1166.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_121.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_1236.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_1244.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_1307.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_1389.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_1424.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_1426.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_1432.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_1499.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_1531.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_1556.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_1651.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_1685.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_1794.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_1927.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_1957.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_1969.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_2040.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_2046.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_2131.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_220.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_2238.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_2261.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_2264.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_2384.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_2422.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_243.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_2509.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_2673.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_2783.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_2789.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_2794.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_2811.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_2857.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_291.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_2952.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_2980.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_3091.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_3107.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_3114.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_315.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_3156.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_3274.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_3303.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_3335.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_3361.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_3474.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_3480.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_3501.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_3554.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_3609.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_3621.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_3662.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_3673.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_3709.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_3782.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_3865.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_4011.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_4014.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_4104.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_4244.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_4257.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_4582.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_4585.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_4593.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_4695.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_470.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_4875.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_4995.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_502.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_5059.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_5069.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_5083.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_5223.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_5256.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_5264.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_5357.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_5482.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_5514.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_5622.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_5625.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_5702.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_5705.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_5726.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_5736.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_5776.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_5787.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_5924.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_5949.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_605.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_6119.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_6235.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_6240.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_6286.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_6380.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_644.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_6458.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_6459.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_6488.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_6521.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_6546.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_6564.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_6607.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_6660.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_6682.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_6774.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_6781.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_6851.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_6937.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_6967.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_7045.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_7090.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_7132.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_7215.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_7238.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_7325.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_7330.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_7386.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_7456.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_7478.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_7489.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_7514.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_7607.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_7943.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_7948.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_7961.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_7998.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_801.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_8082.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_8151.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_8257.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_8290.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_8304.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_8317.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_8476.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_8565.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_8584.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_8588.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_8619.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_8625.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_8713.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_9244.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_9460.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_9527.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_9530.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_9577.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_9710.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_9717.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_9975.jpeg
#   inflating: images/TRAIN/MONOCYTE/_11_9999.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_1154.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_1169.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_127.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_1310.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_1344.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_1347.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_1348.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_1377.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_1380.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_1463.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_1499.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_15.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_1537.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_1551.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_1580.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_1622.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_169.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_1815.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_1899.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_1951.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_2192.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_2213.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_2216.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_2246.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_2251.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_251.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_2688.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_2713.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_2750.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_2790.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_280.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_2815.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_2840.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_2903.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_2998.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_3024.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_3092.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_3112.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_3174.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_3177.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_3202.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_3278.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_3360.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_3406.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_3506.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_3571.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_37.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_3787.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_3801.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_3891.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_3909.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_3964.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_4001.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_4056.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_4269.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_4297.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_4358.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_4418.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_443.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_4487.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_4555.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_4651.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_47.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_4707.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_4708.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_4789.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_4792.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_4826.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_4865.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_4876.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_4913.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_4996.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_5096.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_5188.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_5208.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_5356.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_5395.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_5397.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_5398.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_5430.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_5443.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_5458.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_5481.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_5651.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_5691.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_5826.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_5856.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_5881.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_6115.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_6169.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_6239.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_6278.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_6289.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_6307.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_637.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_6387.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_6388.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_6417.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_6428.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_6481.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_6736.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_6753.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_6780.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_6877.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_6945.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_6952.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_6969.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_7041.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_7061.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_7110.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_7167.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_7226.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_7359.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_7500.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_7513.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_7593.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_7681.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_7733.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_7750.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_786.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_7893.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_7894.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_8034.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_804.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_8124.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_8255.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_8278.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_8318.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_8331.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_8387.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_842.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_844.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_8608.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_8657.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_869.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_8780.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_8834.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_890.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_8911.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_8938.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_9052.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_9078.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_9151.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_9321.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_949.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_9550.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_9564.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_9589.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_9607.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_9656.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_968.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_9820.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_9877.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_989.jpeg
#   inflating: images/TRAIN/MONOCYTE/_12_9929.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_1028.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_1061.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_1123.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_120.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_121.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_1228.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_1236.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_1288.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_1291.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_1343.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_1402.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_1440.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_1485.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_1487.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_150.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_1928.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_2045.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_2082.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_2088.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_2276.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_23.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_2389.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_248.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_2595.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_2740.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_2787.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_279.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_2803.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_2805.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_2808.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_2847.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_2848.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_3068.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_3088.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_3113.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_3121.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_3156.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_3278.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_3318.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_3326.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_3338.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_3396.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_3427.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_351.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_3528.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_3576.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_3582.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_3640.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_3672.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_391.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_4048.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_4140.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_4160.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_4253.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_4463.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_447.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_4484.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_4511.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_4551.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_4587.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_468.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_4786.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_4829.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_483.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_4874.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_488.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_496.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_4977.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_5007.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_5194.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_5234.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_5238.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_5277.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_5395.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_5443.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_5475.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_548.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_5513.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_5649.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_5666.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_5989.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_6045.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_6053.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_6126.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_6165.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_6247.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_6267.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_6300.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_6362.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_6364.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_637.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_6488.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_6503.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_6598.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_6612.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_6625.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_6668.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_6679.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_6764.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_6782.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_6809.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_6867.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_6977.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_7000.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_7035.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_7054.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_735.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_7521.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_7562.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_7570.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_7613.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_7620.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_7678.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_7730.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_7763.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_7781.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_7805.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_7824.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_784.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_7882.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_7883.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_8081.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_8109.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_8145.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_8163.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_8259.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_853.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_8660.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_874.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_8755.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_8765.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_891.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_8918.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_8936.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_8953.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_8962.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_9018.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_9054.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_91.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_9138.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_9139.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_915.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_9177.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_9270.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_9280.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_929.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_9357.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_942.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_9432.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_9467.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_949.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_9640.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_9738.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_9782.jpeg
#   inflating: images/TRAIN/MONOCYTE/_13_9786.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_1040.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_1078.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_1127.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_1129.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_1153.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_117.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_1205.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_1312.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_1348.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_1356.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_1439.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_1514.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_1640.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_1643.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_1723.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_1761.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_1830.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_1836.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_1840.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_1845.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_1949.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_1974.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_1991.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_2021.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_2055.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_2141.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_2161.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_2240.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_2335.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_2413.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_2543.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_2555.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_2576.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_2621.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_2686.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_275.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_2764.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_2807.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_2827.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_296.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_2984.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_3061.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_3160.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_3169.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_3243.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_3253.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_3373.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_3376.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_3410.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_3428.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_3660.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_3705.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_3774.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_3825.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_3840.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_3842.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_3856.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_3881.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_3973.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_4027.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_4075.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_4124.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_4126.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_4237.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_4292.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_4357.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_4456.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_4507.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_4519.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_4541.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_4566.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_4815.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_4847.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_4880.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_4942.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_4987.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_5120.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_5226.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_5304.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_5315.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_5418.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_5537.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_5586.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_5638.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_576.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_5936.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_5969.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_5983.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_6223.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_6333.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_6403.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_6411.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_659.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_661.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_6700.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_6712.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_6742.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_687.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_6898.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_6908.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_6926.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_6938.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_694.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_6971.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_7022.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_7085.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_7158.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_717.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_7270.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_7388.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_7397.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_7424.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_7534.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_7595.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_761.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_7719.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_7722.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_7792.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_7808.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_7884.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_8062.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_8280.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_8338.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_847.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_848.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_8637.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_8721.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_8810.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_8825.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_8954.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_8968.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_8969.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_8974.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_8980.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_9075.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_9115.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_9180.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_9231.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_9272.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_9367.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_9432.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_946.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_9471.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_9515.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_9542.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_959.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_9631.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_9638.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_973.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_9794.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_9825.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_9851.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_9932.jpeg
#   inflating: images/TRAIN/MONOCYTE/_14_9986.jpeg
#   inflating: images/TRAIN/MONOCYTE/_15_1009.jpeg
#   inflating: images/TRAIN/MONOCYTE/_15_1034.jpeg
#   inflating: images/TRAIN/MONOCYTE/_15_1043.jpeg
#   inflating: images/TRAIN/MONOCYTE/_15_1063.jpeg
#   inflating: images/TRAIN/MONOCYTE/_15_1128.jpeg
#   inflating: images/TRAIN/MONOCYTE/_15_1172.jpeg
#   inflating: images/TRAIN/MONOCYTE/_15_1257.jpeg
#   inflating: images/TRAIN/MONOCYTE/_15_1482.jpeg
#   inflating: images/TRAIN/MONOCYTE/_15_1621.jpeg
#   inflating: images/TRAIN/MONOCYTE/_15_1646.jpeg
#   inflating: images/TRAIN/MONOCYTE/_15_1656.jpeg
#   inflating: images/TRAIN/MONOCYTE/_15_1799.jpeg
#   inflating: images/TRAIN/MONOCYTE/_15_1815.jpeg
#   inflating: images/TRAIN/MONOCYTE/_15_1841.jpeg
#   inflating: images/TRAIN/MONOCYTE/_15_1868.jpeg
#   inflating: images/TRAIN/MONOCYTE/_15_1950.jpeg
#   inflating: images/TRAIN/MONOCYTE/_15_2144.jpeg
#   inflating: images/TRAIN/MONOCYTE/_15_2198.jpeg
#   inflating: images/TRAIN/MONOCYTE/_15_2214.jpeg
#   inflating: images/TRAIN/MONOCYTE/_15_2303.jpeg
#   inflating: images/TRAIN/MONOCYTE/_15_2310.jpeg
#   inflating: images/TRAIN/MONOCYTE/_15_2413.jpeg
#   inflating: images/TRAIN/MONOCYTE/_15_2418.jpeg
#   inflating: images/TRAIN/MONOCYTE/_15_2445.jpeg
#   inflating: images/TRAIN/MONOCYTE/_15_2474.jpeg
#   inflating: images/TRAIN/MONOCYTE/_15_2485.jpeg
#   inflating: images/TRAIN/MONOCYTE/_15_2661.jpeg
#   inflating: images/TRAIN/MONOCYTE/_15_2740.jpeg
#   inflating: images/TRAIN/MONOCYTE/_15_2819.jpeg
#   inflating: images/TRAIN/MONOCYTE/_15_2931.jpeg
#   inflating: images/TRAIN/MONOCYTE/_15_2988.jpeg
#   inflating: images/TRAIN/MONOCYTE/_15_304.jpeg
#   inflating: images/TRAIN/MONOCYTE/_15_3105.jpeg
#   inflating: images/TRAIN/MONOCYTE/_15_3249.jpeg
#   inflating: images/TRAIN/MONOCYTE/_15_3256.jpeg
#   inflating: images/TRAIN/MONOCYTE/_15_3379.jpeg
#   inflating: images/TRAIN/MONOCYTE/_15_3510.jpeg
#   inflating: images/TRAIN/MONOCYTE/_15_3561.jpeg
#   inflating: images/TRAIN/MONOCYTE/_15_3806.jpeg
#   inflating: images/TRAIN/MONOCYTE/_15_3843.jpeg
#   inflating: images/TRAIN/MONOCYTE/_15_3873.jpeg
#   inflating: images/TRAIN/MONOCYTE/_15_3920.jpeg
#   inflating: images/TRAIN/MONOCYTE/_15_3962.jpeg
#   inflating: images/TRAIN/MONOCYTE/_15_4.jpeg
#   inflating: images/TRAIN/MONOCYTE/_15_4051.jpeg
#   inflating: images/TRAIN/MONOCYTE/_15_4101.jpeg
#   inflating: images/TRAIN/MONOCYTE/_15_4225.jpeg
#   inflating: images/TRAIN/MONOCYTE/_15_4280.jpeg
#   inflating: images/TRAIN/MONOCYTE/_15_4310.jpeg
#   inflating: images/TRAIN/MONOCYTE/_15_434.jpeg
#   inflating: images/TRAIN/MONOCYTE/_15_4367.jpeg
#   inflating: images/TRAIN/MONOCYTE/_15_4383.jpeg
#   inflating: images/TRAIN/MONOCYTE/_15_4393.jpeg
#   inflating: images/TRAIN/MONOCYTE/_15_4426.jpeg
#   inflating: images/TRAIN/MONOCYTE/_15_4431.jpeg
#   inflating: images/TRAIN/MONOCYTE/_15_4451.jpeg
#   inflating: images/TRAIN/MONOCYTE/_15_4561.jpeg
#   inflating: images/TRAIN/MONOCYTE/_15_4615.jpeg
#   inflating: images/TRAIN/MONOCYTE/_15_465.jpeg
#   inflating: images/TRAIN/MONOCYTE/_15_4671.jpeg
#   inflating: images/TRAIN/MONOCYTE/_15_4673.jpeg
#   inflating: images/TRAIN/MONOCYTE/_15_4676.jpeg
#   inflating: images/TRAIN/MONOCYTE/_15_4793.jpeg
#   inflating: images/TRAIN/MONOCYTE/_15_4867.jpeg
#   inflating: images/TRAIN/MONOCYTE/_15_4883.jpeg
#   inflating: images/TRAIN/MONOCYTE/_15_4976.jpeg
#   inflating: images/TRAIN/MONOCYTE/_15_501.jpeg
#   inflating: images/TRAIN/MONOCYTE/_15_5045.jpeg
#   inflating: images/TRAIN/MONOCYTE/_15_5081.jpeg
#   inflating: images/TRAIN/MONOCYTE/_15_5097.jpeg
#   inflating: images/TRAIN/MONOCYTE/_15_5125.jpeg
# ...
#   inflating: images/TRAIN/NEUTROPHIL/_87_3286.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_87_4888.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_87_586.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_87_6578.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_87_6959.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_87_8510.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_87_9514.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_87_9772.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_88_1540.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_88_174.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_88_1818.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_88_1825.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_88_2474.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_88_255.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_88_302.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_88_3023.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_88_3626.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_88_3758.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_88_4317.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_88_6872.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_88_740.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_88_8369.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_88_8453.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_88_9102.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_89_1191.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_89_127.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_89_1639.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_89_189.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_89_2263.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_89_2346.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_89_4086.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_89_4799.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_89_5143.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_89_5819.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_89_748.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_89_7693.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_89_7835.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_89_8238.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_89_8314.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_89_9128.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_8_13.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_8_1761.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_8_1833.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_8_2027.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_8_2196.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_8_2806.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_8_3340.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_8_484.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_8_6610.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_8_6705.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_8_730.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_8_7306.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_8_8434.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_8_8497.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_8_9175.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_8_9436.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_90_1203.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_90_1791.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_90_1804.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_90_2243.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_90_3987.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_90_5011.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_90_5184.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_90_5348.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_90_5510.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_90_5995.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_90_6015.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_90_683.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_90_688.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_90_8169.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_90_8540.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_90_9108.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_91_1459.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_91_3620.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_91_3722.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_91_6028.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_91_6104.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_91_6144.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_91_6154.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_91_6181.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_91_6390.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_91_6801.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_91_7022.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_91_7111.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_91_7569.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_91_8777.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_91_9118.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_91_9687.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_92_1511.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_92_1719.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_92_1830.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_92_2506.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_92_3019.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_92_3898.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_92_3953.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_92_4251.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_92_5602.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_92_5815.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_92_7626.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_92_786.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_92_8748.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_92_9391.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_92_9847.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_92_9917.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_93_200.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_93_2935.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_93_3588.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_93_4089.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_93_4614.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_93_5386.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_93_5801.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_93_6368.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_93_7256.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_93_7979.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_93_8429.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_93_8506.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_93_8688.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_93_9019.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_93_9519.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_93_9651.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_94_1597.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_94_1970.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_94_2121.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_94_255.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_94_2573.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_94_3353.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_94_4199.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_94_4337.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_94_4992.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_94_5772.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_94_5893.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_94_602.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_94_6855.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_94_6913.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_94_7452.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_94_9898.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_95_2008.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_95_2550.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_95_3535.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_95_3865.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_95_4386.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_95_4402.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_95_4501.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_95_5558.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_95_5682.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_95_5911.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_95_7268.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_95_7399.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_95_8622.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_95_8927.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_95_9448.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_95_9932.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_96_1884.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_96_2248.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_96_2618.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_96_3254.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_96_4564.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_96_4803.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_96_4974.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_96_504.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_96_5686.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_96_5993.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_96_6379.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_96_7225.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_96_7391.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_96_8552.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_96_8604.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_96_9222.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_97_1083.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_97_1407.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_97_2291.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_97_2324.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_97_266.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_97_5018.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_97_555.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_97_6363.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_97_6817.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_97_7103.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_97_7492.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_97_7779.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_97_8216.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_97_8576.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_97_9818.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_97_9906.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_98_156.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_98_1601.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_98_1701.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_98_286.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_98_3060.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_98_3745.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_98_5078.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_98_5084.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_98_5779.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_98_5910.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_98_6603.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_98_6760.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_98_7150.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_98_7254.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_98_9274.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_98_9475.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_99_1394.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_99_2791.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_99_475.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_99_5644.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_99_6065.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_99_670.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_99_7087.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_99_7107.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_99_7158.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_99_7565.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_99_7999.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_99_8063.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_99_8096.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_99_8689.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_99_8759.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_99_8952.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_9_1276.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_9_2663.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_9_3730.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_9_4662.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_9_5057.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_9_5125.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_9_5178.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_9_5208.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_9_6001.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_9_6022.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_9_7478.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_9_7514.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_9_8230.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_9_8636.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_9_9075.jpeg
#   inflating: images/TRAIN/NEUTROPHIL/_9_9644.jpeg
#    creating: images/VAL/
#    creating: images/VAL/EOSINOPHIL/
#   inflating: images/VAL/EOSINOPHIL/_0_5239.jpeg
#   inflating: images/VAL/EOSINOPHIL/_10_5476.jpeg
#   inflating: images/VAL/EOSINOPHIL/_11_9310.jpeg
#   inflating: images/VAL/EOSINOPHIL/_12_2599.jpeg
#   inflating: images/VAL/EOSINOPHIL/_1_5031.jpeg
#   inflating: images/VAL/EOSINOPHIL/_2_1226.jpeg
#   inflating: images/VAL/EOSINOPHIL/_3_625.jpeg
#   inflating: images/VAL/EOSINOPHIL/_4_8814.jpeg
#   inflating: images/VAL/EOSINOPHIL/_5_1744.jpeg
#   inflating: images/VAL/EOSINOPHIL/_6_7701.jpeg
#   inflating: images/VAL/EOSINOPHIL/_7_2284.jpeg
#   inflating: images/VAL/EOSINOPHIL/_8_8479.jpeg
#   inflating: images/VAL/EOSINOPHIL/_9_2814.jpeg
#    creating: images/VAL/LYMPHOCYTE/
#   inflating: images/VAL/LYMPHOCYTE/_0_3975.jpeg
#   inflating: images/VAL/LYMPHOCYTE/_1_4044.jpeg
#   inflating: images/VAL/LYMPHOCYTE/_2_6981.jpeg
#   inflating: images/VAL/LYMPHOCYTE/_3_7545.jpeg
#   inflating: images/VAL/LYMPHOCYTE/_4_2908.jpeg
#   inflating: images/VAL/LYMPHOCYTE/_5_1558.jpeg
#    creating: images/VAL/MONOCYTE/
#   inflating: images/VAL/MONOCYTE/_0_5020.jpeg
#   inflating: images/VAL/MONOCYTE/_1_4511.jpeg
#   inflating: images/VAL/MONOCYTE/_2_4392.jpeg
#   inflating: images/VAL/MONOCYTE/_3_9457.jpeg
#    creating: images/VAL/NEUTROPHIL/
#   inflating: images/VAL/NEUTROPHIL/_0_1966.jpeg
#   inflating: images/VAL/NEUTROPHIL/_10_170.jpeg
#   inflating: images/VAL/NEUTROPHIL/_11_1721.jpeg
#   inflating: images/VAL/NEUTROPHIL/_12_4753.jpeg
#   inflating: images/VAL/NEUTROPHIL/_13_7598.jpeg
#   inflating: images/VAL/NEUTROPHIL/_14_4489.jpeg
#   inflating: images/VAL/NEUTROPHIL/_15_9520.jpeg
#   inflating: images/VAL/NEUTROPHIL/_16_3623.jpeg
#   inflating: images/VAL/NEUTROPHIL/_17_9949.jpeg
#   inflating: images/VAL/NEUTROPHIL/_18_4469.jpeg
#   inflating: images/VAL/NEUTROPHIL/_19_4489.jpeg
#   inflating: images/VAL/NEUTROPHIL/_1_2118.jpeg
#   inflating: images/VAL/NEUTROPHIL/_20_9752.jpeg
#   inflating: images/VAL/NEUTROPHIL/_21_6827.jpeg
#   inflating: images/VAL/NEUTROPHIL/_22_2921.jpeg
#   inflating: images/VAL/NEUTROPHIL/_23_6221.jpeg
#   inflating: images/VAL/NEUTROPHIL/_24_8655.jpeg
#   inflating: images/VAL/NEUTROPHIL/_25_8686.jpeg
#   inflating: images/VAL/NEUTROPHIL/_26_3624.jpeg
#   inflating: images/VAL/NEUTROPHIL/_27_4190.jpeg
#   inflating: images/VAL/NEUTROPHIL/_28_4752.jpeg
#   inflating: images/VAL/NEUTROPHIL/_29_1866.jpeg
#   inflating: images/VAL/NEUTROPHIL/_2_1918.jpeg
#   inflating: images/VAL/NEUTROPHIL/_30_4636.jpeg
#   inflating: images/VAL/NEUTROPHIL/_31_3491.jpeg
#   inflating: images/VAL/NEUTROPHIL/_32_2063.jpeg
#   inflating: images/VAL/NEUTROPHIL/_33_390.jpeg
#   inflating: images/VAL/NEUTROPHIL/_34_3330.jpeg
#   inflating: images/VAL/NEUTROPHIL/_35_5434.jpeg
#   inflating: images/VAL/NEUTROPHIL/_36_5118.jpeg
#   inflating: images/VAL/NEUTROPHIL/_37_3964.jpeg
#   inflating: images/VAL/NEUTROPHIL/_38_4586.jpeg
#   inflating: images/VAL/NEUTROPHIL/_39_1103.jpeg
#   inflating: images/VAL/NEUTROPHIL/_3_1003.jpeg
#   inflating: images/VAL/NEUTROPHIL/_40_7251.jpeg
#   inflating: images/VAL/NEUTROPHIL/_41_2530.jpeg
#   inflating: images/VAL/NEUTROPHIL/_42_8715.jpeg
#   inflating: images/VAL/NEUTROPHIL/_43_289.jpeg
#   inflating: images/VAL/NEUTROPHIL/_44_8974.jpeg
#   inflating: images/VAL/NEUTROPHIL/_45_5733.jpeg
#   inflating: images/VAL/NEUTROPHIL/_46_2162.jpeg
#   inflating: images/VAL/NEUTROPHIL/_47_8207.jpeg
#   inflating: images/VAL/NEUTROPHIL/_4_1395.jpeg
#   inflating: images/VAL/NEUTROPHIL/_5_1480.jpeg
#   inflating: images/VAL/NEUTROPHIL/_6_2289.jpeg
#   inflating: images/VAL/NEUTROPHIL/_7_8956.jpeg
#   inflating: images/VAL/NEUTROPHIL/_8_6417.jpeg
#   inflating: images/VAL/NEUTROPHIL/_9_8786.jpeg

# %% [markdown]
# Implementa la mejor red neuronal posible. Tú decides si usas una red creada por ti mismo o si empleas transfer-learning. Entrena la red con los datos en la carpeta "TRAIN" y usa los datos en "VAL" como validación.
#
# Para medir el performance final, realiza las inferencias sobre los datos del conjunto "TEST" y computa el accuracy sobre el conjunto de test. El accuracy es la proporción de imágenes para las cuales la predicción es correcta. IMPORTANTE: el accuracy de test se calcula una sola vez cuando hayas finalizado todos tus experimentos. Para tomar decisiones sobre el modelo y sus hiperparámetros solo puedes usar el conjunto de entrenamiento y validación.
#
# Detalla todos los experimentos que hiciste y cómo llegaste a la mejor red neuronal reportada. Discute los resultados, comparando los distintos experimentos que tomaste en cuenta y responde a la pregunta: Porqué tu modelo final fue el mejor de todo lo que probaste?
#
# IMPORTANTE: Evita el overfitting a toda costa. Un modelo con overfitting es aquel que durante el entrenamiento las curvas de loss/accuracy para datos de entrenamiento y validación se separan considerablemente.
#
# Éxitos!

# %% [markdown]
# ## Implementación
# Dado el siguiente paper "Transfer learning with pre-trained deep convolutional neural networks for serous cell classification", se elige una red residual para hacer el transfer learning.

# %%
#librerias
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
import numpy as np
import matplotlib.pyplot as plt
from torchvision import datasets, models, transforms
import time
import os
import copy
import sys
import copy

from torchvision.io import read_image
from PIL import Image
from sklearn.metrics import confusion_matrix
from time import perf_counter

import seaborn as sn
from sklearn.metrics import accuracy_score

torch.manual_seed(42)

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cpu

# %% [markdown]
# ### Data

# %% [markdown]
# ### Normalización de Datos

# %%
def norm_std(dataloader):

  mean        = 0
  std         = 0
  nb_samples  = 0

  for data,y in dataloader:
    batch_samples = data.size(0)
    data = data.view(batch_samples, data.size(1), -1)
    mean += data.mean(2).sum(0)
    std += data.std(2).sum(0)
    nb_samples += batch_samples

  mean /= nb_samples
  std /= nb_samples
  return mean,std

# %%
# creating Location of data: train, validation, test
data='./images/'
batch_size = 32

train_path=os.path.join(data,'TRAIN')
valid_path=os.path.join(data,'VAL')
test_path=os.path.join(data,'TEST')

# %%
datafile=datasets.ImageFolder(train_path,transform=transforms.Compose([transforms.Resize(size=(224,224)), transforms.ToTensor()]))
normalizationset = torch.utils.data.DataLoader(datafile,batch_size,shuffle=True)

# %%
mean, std = norm_std(normalizationset)

# %% [markdown]
# #### Data loaders

# %%
#transformers 
data_transforms = {
    'TRAIN':
    transforms.Compose([
        transforms.Resize(size=(224,224)), 
        transforms.ToTensor(),
        transforms.Normalize(mean,std)#[0.6788, 0.6414, 0.6606], [0.2580, 0.2576, 0.2550]), 
        ]),
      
    'TRAIN_AUG': 
    transforms.Compose([
          transforms.ColorJitter(),
          transforms.RandomHorizontalFlip(),
          transforms.RandomRotation(10),
          transforms.Resize(size=(224,224)),
          transforms.ToTensor(),
          transforms.Normalize(mean,std)#[0.6788, 0.6414, 0.6606], [0.2580, 0.2576, 0.2550]),
      ]),

    'VAL':
    transforms.Compose([
        transforms.Resize(size=(224,224)),
        transforms.ToTensor(),
        transforms.Normalize(mean,std)
        ]),

    'TEST':
    transforms.Compose([
        transforms.Resize(size=(224,224)),
        transforms.ToTensor(),
        transforms.Normalize(mean,std)
        ]),
     }

# %%
# creating Datasets to each of  folder created in prev
train_file=datasets.ImageFolder(train_path,transform=data_transforms['TRAIN'])
trainAug_file = datasets.ImageFolder(train_path,transform=data_transforms['TRAIN_AUG'])
valid_file=datasets.ImageFolder(valid_path,transform=data_transforms['VAL'])
test_file=datasets.ImageFolder(test_path,transform=data_transforms['TEST'])


#Creating loaders for the dataset
dataloaders={
    'train':torch.utils.data.DataLoader(train_file,batch_size,shuffle=True),
    'train_aug': torch.utils.data.DataLoader(train_file,batch_size,shuffle = True),
    'val':torch.utils.data.DataLoader(valid_file,batch_size,shuffle=True),
    'test': torch.utils.data.DataLoader(test_file,batch_size,shuffle=True)
}

# %%
# Se ven algunas imágenes que se utilizan en entrenamiento.
# Se utiliza una adaptación de una función encontrada en página: https://www.guru99.com/transfer-learning.html

images, labels = next(iter(dataloaders['train']))
rows = 4
columns = 4
fig=plt.figure(figsize=(20,20))
for i in range(16):
   fig.add_subplot(rows, columns, i+1)
   plt.title(train_file.classes[labels[i]])
   img = images[i].numpy().transpose((1, 2, 0))
   img = std * img + mean
   plt.imshow(img)
plt.show()

# %%
images, labels = next(iter(dataloaders['train_aug']))
rows = 4
columns = 4
fig=plt.figure(figsize=(20,20))
for i in range(16):
   fig.add_subplot(rows, columns, i+1)
   plt.title(train_file.classes[labels[i]])
   img = images[i].numpy().transpose((1, 2, 0))
   img = std * img + mean
   plt.imshow(img)
plt.show()

# %% [markdown]
# ### Funciones

# %%
#Para evitar el overfitting, dado una tolerancia en épocas.
def earlyStop(train_loss, valid_loss, train_loss_epoch, valid_loss_epoch, patience):
  ntrain = len(train_loss_epoch)
  nvalid = len(valid_loss_epoch)
  average_train = 0
  average_valid = 0
  counter = 0

  if ntrain < patience:
    average_train = np.average(train_loss_epoch)
    average_valid = np.average(valid_loss_epoch)

  if ntrain >= patience:
    ntrain -= 1
    nvalid -= 1
    while counter != patience:
      average_train += train_loss_epoch[ntrain]
      average_valid += valid_loss_epoch[nvalid]
      ntrain -= 1
      nvalid -= 1
      counter +=1
    average_train = average_train/(patience)
    average_valid = average_valid/(patience)
  
  if (train_loss <= average_train) and (valid_loss > average_valid):  # detener, guardar checkpoint
    return True

  else: return False

# %%
def train_model2(num_epoch, model, dataloader, dataaugmentation, criterion, optimizer, filepath, avg, n_save):
  global device

  train_losses = []       # to track the training loss as the model trains
  valid_losses = []       # to track the validation loss as the model trains
  
  avg_train_losses = []   # to track the average training loss per epoch as the model trains
  avg_valid_losses = []   # to track the average validation loss per epoch as the model trains



  for epoch in range(num_epoch):
    if dataaugmentation == False:
      dataloader_val = dataloader['val'] 
      dataloader_train = dataloader['train'] 
    else:
      dataloader_val = dataloader['val']
      dataloader_train = dataloader['train_aug']
      #if dataaugmentation == True:
      #  dataloader_val = dataloader['val']
      #  dataloader_train = dataloader['train_aug']
      try:
        model.train()

        # Train on the current epoch
        for x_train, y_train in dataloader_train:
            inputs = x_train.to(device)
            labels = y_train.to(device).long()

            # zero the parameter gradients
            optimizer.zero_grad()

            # forward + backward + optimize
            outputs = model(inputs)

            loss = criterion(outputs, labels).cuda()
            loss.backward()
            optimizer.step()
            train_losses.append(loss.item())

        # Compute validation loss and accuracy for current epoch
        model.eval()
        with torch.no_grad():  
          for x_val, y_val in dataloader_val:
              inputs = x_val.to(device)
              labels = y_val.to(device).long()

              outputs = model(inputs)
              # Calcular loss de validación
              loss = criterion(outputs, labels).cuda()
              # record validation loss
              valid_losses.append(loss.item())

        # No se debe guardar checkpoints en cada época (guardarlos cada 50 épocas)
        train_loss = np.average(train_losses)
        valid_loss = np.average(valid_losses)
        avg_train_losses.append(train_loss)
        avg_valid_losses.append(valid_loss)

        # limpiar listas para la proxima epoca:
        train_losses = []
        valid_losses = []

        # imprimir resultados por epoca:  
        sys.stdout.write(f"\rÉpoca: {epoch} Training Loss: {train_loss} Validation Loss: {valid_loss}")

        # stop = earlyStop(train_loss, valid_loss, avg_train_losses, avg_valid_losses, avg)
        
        # if  stop == True:  # caso en que hay que deterner
        #     # cargar checkpoint, o guardar
        #     print(" - Early stopping")
        #     break

        # condición de checkpoint:
        if (epoch % n_save) == 0:
          torch.save(model.state_dict(), filepath)     
      
      # Interrupt Training
      except KeyboardInterrupt:
        print("\nEntrenamiento interrumpido")
        break

  # load the last checkpoint with the best model
  #model.load_state_dict(torch.load(filepath))

  print('\nEntrenamiento finalizado')
  return model, avg_train_losses, avg_valid_losses

# %%
def predict(model, dataloader, plot_title):
  global device
  label_real = []
  pred_model = []
  model.eval()
  with torch.no_grad():
    #for x,y in enumerate(dataloader, 0):
    for x,y in dataloader:
      inputs = x.to(device)
      labels = y.to(device)#.long()

      outputs= model(inputs)
      # print(f"prediccion: {outputs}")
      pred = torch.argmax(outputs, 1)

      label_real = np.concatenate((label_real, labels.cpu().numpy()), axis=None)
      pred_model = np.concatenate((pred_model, pred.cpu().numpy()), axis=None)
  #     print(f"real: {label_real[0]}")
  #     print(f"pred: {pred_model[0]}")
  #     print(len(label_real), len(pred_model))

      
  # print(label_real)
  # print(pred_model)
      
  CM = confusion_matrix(label_real, pred_model, normalize= 'true')
  plt.figure(figsize = (10,7))
  sn.heatmap(CM, annot=True)
  plt.xlabel("Predicción")
  plt.ylabel("Observación")
  plt.title(plot_title)

  accuracy = accuracy_score(label_real, pred_model, normalize=True)
  print(f'accuracy: {accuracy}')
  return accuracy

# %%
def accuracy(y_pred, y_real):
  valor, posicion = torch.max(y_pred, dim = 1)
  pred = (posicion == y_real).float()
  accuracy = pred.sum()/len(pred)
  return accuracy

# %% [markdown]
# #### Gráficos

# %%
def plot(validation,train, plot_title):
  #minposs = validation.index(min(validation))+1 
  #plt.axvline(minposs, linestyle='--', color='r',label='Early Stopping Checkpoint')  # sirve para ver más o menos donde se tiene que detener
  #plt.title('Curva Loss - Epoch')
  plt.figure(figsize = (10,7))
  plt.plot(train, label='Train Loss')
  plt.plot(validation, label='Validation Loss')
  plt.legend()
  plt.xlabel('Epoch')
  plt.ylabel('Loss')
  plt.title(plot_title)

# %%
def curvas_loss(early_epoca, perdidas_train, perdidas_val):
  try:
    plt.plot([e for e in range(early_epoca+1)], perdidas_train, label='Entrenamiento')
    plt.plot([e for e in range(early_epoca+1)], perdidas_val, label='Validacion')
  except:
    plt.plot([e for e in range(early_epoca)], perdidas_train, label='Entrenamiento')
    plt.plot([e for e in range(early_epoca)], perdidas_val, label='Validacion')
  plt.xlabel('Epocas')
  plt.ylabel('Valor')
  plt.title(f'Perdidas de entrenamiento/validacion para el modelo')
  plt.legend()
  plt.show()

# %% [markdown]
# # Entrenar Modelo

# %% [markdown]
# ## Resnet18

# %% [markdown]
# ### Con Data Augmentation

# %%
model_ft = models.resnet18(pretrained=True)

## freeze the layers
for param in model_ft.parameters():
    param.requires_grad = False

num_ftrs = model_ft.fc.in_features

# Alternatively, it can be generalized to nn.Linear(num_ftrs, len(class_names)).
model_ft.fc = nn.Linear(num_ftrs, len(train_file.classes))
model_ft = model_ft.to(device)

criterion = nn.CrossEntropyLoss()
optimizer_ft = optim.Adam(model_ft.parameters(), lr=0.001)

# Decay LR by a factor of 0.1 every 7 epochs
# exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=7, gamma=0.1)
# Out:
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:209: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   f"The parameter '{pretrained_param}' is deprecated since 0.13 and will be removed in 0.15, "
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
model_ft2 = copy.deepcopy(model_ft)

num_epochs = 25
batch_size = 150
n_save = 5
avg = 10
data_augmentation = True
file_path = 'model_ft18_DA.pth'

model_ft_trained = train_model2(num_epochs, model_ft2, dataloaders, data_augmentation, criterion, optimizer_ft, file_path, avg, n_save)
# Out:
# Época: 9 Training Loss: 1.507603346537321 Validation Loss: 1.3516608079274495

# %%
plot(model_ft_trained[2], model_ft_trained[1],'Curvas de Perdidad Modelo 1')
predict(model_ft_trained[0], dataloaders['test'], 'Matriz de Confusión Modelo 1')

# %% [markdown]
# ### Sin Data Augmentation

# %%
model_ft2 = copy.deepcopy(model_ft)

num_epochs = 25
batch_size = 150
n_save = 5
avg = 10
data_augmentation = False
file_path = 'model_ft18_sinDA.pth'

model_ft_trained_sinDA = train_model2(num_epochs, model_ft2, dataloaders, data_augmentation, criterion, optimizer_ft, file_path, avg, n_save)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-51-ff19d6036446> in <module>
#       8 file_path = 'model_ft18_sinDA.pth'
#       9
# ---> 10 model_ft_trained_sinDA = train_model2(num_epochs, model_ft2, dataloaders, data_augmentation, criterion, optimizer_ft, file_path, avg, n_save)
#
# <ipython-input-43-5203b4b69009> in train_model2(num_epoch, model, dataloader, dataaugmentation, criterion, optimizer, filepath, avg, n_save)
#      82
#      83   # load the last checkpoint with the best model
# ---> 84   model.load_state_dict(torch.load(filepath))
#      85
#      86   print('\nEntrenamiento finalizado')
#
# /usr/local/lib/python3.7/dist-packages/torch/serialization.py in load(f, map_location, pickle_module, **pickle_load_args)
#     697         pickle_load_args['encoding'] = 'utf-8'
#     698
# --> 699     with _open_file_like(f, 'rb') as opened_file:
#     700         if _is_zipfile(opened_file):
#     701             # The zipfile reader is going to advance the current file position.
#
# /usr/local/lib/python3.7/dist-packages/torch/serialization.py in _open_file_like(name_or_buffer, mode)
#     228 def _open_file_like(name_or_buffer, mode):
#     229     if _is_path(name_or_buffer):
# --> 230         return _open_file(name_or_buffer, mode)
#     231     else:
#     232         if 'w' in mode:
#
# /usr/local/lib/python3.7/dist-packages/torch/serialization.py in __init__(self, name, mode)
#     209 class _open_file(_opener):
#     210     def __init__(self, name, mode):
# --> 211         super(_open_file, self).__init__(open(name, mode))
#     212
#     213     def __exit__(self, *args):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'model_ft18_sinDA.pth'

# %%
plot(model_ft_trained_sinDA[2], model_ft_trained_sinDA[1],'Curvas de Perdidad Modelo 2')
predict(model_ft_trained_sinDA[0], dataloaders['test'], 'Matriz de Confusión Modelo 2')

# %% [markdown]
# ## DenseNet

# %%
model = torch.hub.load('pytorch/vision:v0.10.0', 'densenet121', pretrained=True)
# or any of these variants
# model = torch.hub.load('pytorch/vision:v0.10.0', 'densenet169', pretrained=True)
# model = torch.hub.load('pytorch/vision:v0.10.0', 'densenet201', pretrained=True)
# model = torch.hub.load('pytorch/vision:v0.10.0', 'densenet161', pretrained=True)
# Out:
# Downloading: "https://github.com/pytorch/vision/zipball/v0.10.0" to /root/.cache/torch/hub/v0.10.0.zip
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:209: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   f"The parameter '{pretrained_param}' is deprecated since 0.13 and will be removed in 0.15, "
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=DenseNet121_Weights.IMAGENET1K_V1`. You can also use `weights=DenseNet121_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/densenet121-a639ec97.pth" to /root/.cache/torch/hub/checkpoints/densenet121-a639ec97.pth
#   0%|          | 0.00/30.8M [00:00<?, ?B/s]

# %%
for param in model.parameters():
    param.requires_grad = False

#num_ftrs = model.in_features

# Alternatively, it can be generalized to nn.Linear(num_ftrs, len(class_names)).
model.classifier = nn.Linear(1024, len(train_file.classes))
model = model.to(device)

# %%
criterion = nn.CrossEntropyLoss()
optimizer_ft = optim.Adam(model.parameters(), lr=0.001)

# %%
model_ft2 = copy.deepcopy(model)

num_epochs = 25
batch_size = 150
n_save = 5
avg = 10
data_augmentation = False
file_path = 'model_DenseNet_sinDA.pth'

model_ft_trained_sinDA = train_model2(num_epochs, model_ft2, dataloaders, data_augmentation, criterion, optimizer_ft, file_path, avg, n_save)

# %%
predict(model_DenseNet_sinDA.pth, dataloaders['test'], 'Matriz de Confusión Modelo 3')

# %% [markdown]
# ## EfficientNet

# %%
model_transfer = EfficientNet.from_pretrained('efficientnet-b7')
